# %% [markdown]
# <a href="https://colab.research.google.com/github/GandaKen/myprojects/blob/master/Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install tweepy
# !pip install vaderSentiment
# Out:
# ...
#     100% |████████████████████████████████| 133kB 6.0MB/s
# ...

# %%
import tweepy
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# /usr/local/lib/python3.6/dist-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
#My Twitter API Authentication Variables
consumer_key = '7ukiEnZlZCTpzmCFnB78Blkjb'
consumer_secret = 'PUyONlBghJhTJaWTku6KhviATQVzqgfBQ9QBCh0MH4OKNFVeHR'
access_token = '960610040921993217-jiKO2Ab2ws3Mdp9WBLUkooDVEE2AKUY'
access_token_secret = '4KTr7kff8KzOfTiVnmi1Jngrz8u7yRYiXOw5TEjCNcZn2'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

tweets = api.search('Artificial Intelligence', count=200)


data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

display(data.head(10))


print(tweets[0].created_at)
# Out:
#                                               Tweets
# 0  RT @TheTweetOfGod: Artificial intelligence isn...
# 1  RT @TheTweetOfGod: Artificial intelligence isn...
# 2  RT @TheTweetOfGod: Artificial intelligence isn...
# 3  RT @CoE_HRightsRLaw: #AIFINCoE: Die Schlussfol...
# 4  RT @stanfordnlp: Interested in spending some y...
# 5  RT @IrenaTadic1: EU issues ethics guidelines f...
# 6  Building Sustainable Societies with Artificial...
# 7  RT @TheTweetOfGod: Artificial intelligence isn...
# 8  Joining forces on embedded computing for artif...
# 9    https://t.co/X9Kh2mlDkm https://t.co/ITNlTa51yn
# 2019-04-11 05:44:51

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
sid = SentimentIntensityAnalyzer()


listy = []

for index, row in data.iterrows():
  ss = sid.polarity_scores(row["Tweets"])
  listy.append(ss)
  
se = pd.Series(listy)
data['polarity'] = se.values

display(data.head(100))
# Out:
#                                                Tweets  \
# 0   RT @TheTweetOfGod: Artificial intelligence isn...
# 1   RT @TheTweetOfGod: Artificial intelligence isn...
# 2   RT @TheTweetOfGod: Artificial intelligence isn...
# 3   RT @CoE_HRightsRLaw: #AIFINCoE: Die Schlussfol...
# 4   RT @stanfordnlp: Interested in spending some y...
# 5   RT @IrenaTadic1: EU issues ethics guidelines f...
# 6   Building Sustainable Societies with Artificial...
# 7   RT @TheTweetOfGod: Artificial intelligence isn...
# 8   Joining forces on embedded computing for artif...
# 9     https://t.co/X9Kh2mlDkm https://t.co/ITNlTa51yn
# 10  Nine Companies Are Shaping The Future Of Artif...
# 11  Nine Companies Are Shaping The Future Of Artif...
# 12  RT @TheTweetOfGod: Artificial intelligence isn...
# 13  📰 How #ArtificialIntelligence Is Transforming ...
# 14  RT @Marcpalahi: In the digital era, the era of...
# 15  RT @mlamons1: Artificial Intelligence with Int...
# ...
